# %%
import pandas as pd
import numpy as np

# 한글폰트 설정, 그래프 마이너스 표시 설정
import matplotlib
from matplotlib import font_manager, rc
from matplotlib import pyplot as plt
import platform
import seaborn as sns

if platform.system() == 'Windows':
# 윈도우인 경우
    font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
else:    
# Mac 인 경우
    rc('font', family='AppleGothic')

matplotlib.rcParams['axes.unicode_minus'] = False

# %%
train = pd.read_csv('./Data/train_df_errno.csv')
test = pd.read_csv('./Data/test_df.csv')
age = pd.read_csv('./Data/age_gender_info.csv')

train.shape, test.shape, age.shape
# Out:
# ((2896, 23), (1008, 21), (16, 23))

# %%
train.columns
# Out:
# Index(['단지코드', '총세대수', '임대건물구분', '지역', '공급유형', '전용면적', '전용면적별세대수', '공가수',
#        '자격유형', '임대보증금', '임대료', '10분내지하철수', '10분내버스정류장수', '단지내주차면수',
#        '단지코드_Type', '임대건물구분_lbl', '지역_lbl', '공급유형_lbl', '자격유형_lbl', '단지코드_lbl',
#        'qcut_총세대수', '등록차량수', 'log_등록차량수'],
#       dtype='object')

# %%
all_df = pd.concat([train, test], join='inner', ignore_index=True)
all_df.isnull().sum()
# Out:
# 단지코드            0
# 총세대수            0
# 임대건물구분          0
# 지역              0
# 공급유형            0
# 전용면적            0
# 전용면적별세대수        0
# 공가수             0
# 자격유형            0
# 임대보증금         749
# 임대료           749
# 10분내지하철수      249
# 10분내버스정류장수      0
# 단지내주차면수         0
# 단지코드_Type       0
# 임대건물구분_lbl      0
# 지역_lbl          0
# 공급유형_lbl        0
# 자격유형_lbl        0
# 단지코드_lbl        0
# qcut_총세대수       0
# dtype: int64

# %%
print('전체 단지 수: ', train['단지코드'].nunique())
print('지하철 결측치 단지 수: ', train.loc[train['10분내지하철수'].isnull()]['단지코드'].nunique())
print('지하철 결측치 단지: ', train.loc[train['10분내지하철수'].isnull()]['단지코드'].unique())
print('지하철 결측치 단지 지역: ', train.loc[train['10분내지하철수'].isnull()]['지역'].unique())
# Out:
# 전체 단지 수:  414
# 지하철 결측치 단지 수:  20
# 지하철 결측치 단지:  ['C1312' 'C1874' 'C1424' 'C2100' 'C2520' 'C1616' 'C1704' 'C2258' 'C1068'
#  'C1983' 'C2216' 'C2644' 'C1005' 'C1004' 'C1875' 'C2156' 'C1175' 'C2583'
#  'N2431' 'C1350']
# 지하철 결측치 단지 지역:  ['충청남도' '대전광역시' '경상남도']

# %%
print('전체 단지 수: ', test['단지코드'].nunique())
print('지하철 결측치 단지 수: ', test.loc[test['10분내지하철수'].isnull()]['단지코드'].nunique())
print('지하철 결측치 단지: ', test.loc[test['10분내지하철수'].isnull()]['단지코드'].unique())
print('지하철 결측치 단지 지역: ', test.loc[test['10분내지하철수'].isnull()]['지역'].unique())
# Out:
# 전체 단지 수:  147
# 지하철 결측치 단지 수:  4
# 지하철 결측치 단지:  ['C1472' 'C1083' 'C2177' 'C1318']
# 지하철 결측치 단지 지역:  ['충청남도' '대전광역시']

# %%
train.loc[(train['임대건물구분'] != '상가') & (train['임대보증금'].isnull())]
# Out:
#        단지코드  총세대수 임대건물구분     지역  공급유형   전용면적  전용면적별세대수  공가수 자격유형 임대보증금  ...  \
# 2309  C1350  1401    아파트  대전광역시  공공분양  74.94       317  2.0    D   NaN  ...
# 2310  C1350  1401    아파트  대전광역시  공공분양  74.94       137  2.0    D   NaN  ...
# 2311  C1350  1401    아파트  대전광역시  공공분양  74.94        22  2.0    D   NaN  ...
# 2312  C1350  1401    아파트  대전광역시  공공분양  84.94       164  2.0    D   NaN  ...
# 2313  C1350  1401    아파트  대전광역시  공공분양  84.94        19  2.0    D   NaN  ...
# 2314  C1350  1401    아파트  대전광역시  공공분양  84.96        26  2.0    D   NaN  ...
# 2315  C1350  1401    아파트  대전광역시  공공분양  84.97        26  2.0    D   NaN  ...
#
#      단지내주차면수  단지코드_Type  임대건물구분_lbl  지역_lbl  공급유형_lbl  자격유형_lbl  단지코드_lbl  \
# 2309  1636.0        3.0           1       2         8         4       117
# 2310  1636.0        3.0           1       2         8         4       117
# 2311  1636.0        3.0           1       2         8         4       117
# 2312  1636.0        3.0           1       2         8         4       117
# 2313  1636.0        3.0           1       2         8         4       117
# 2314  1636.0        3.0           1       2         8         4       117
# 2315  1636.0        3.0           1       2         8         4       117
#
#       qcut_총세대수   등록차량수  log_등록차량수
# 2309          4  2315.0   7.747597
# 2310          4  2315.0   7.747597
# 2311          4  2315.0   7.747597
# 2312          4  2315.0   7.747597
# 2313          4  2315.0   7.747597
# 2314          4  2315.0   7.747597
# 2315          4  2315.0   7.747597
#
# [7 rows x 23 columns]

# %%
test.loc[(test['임대건물구분'] != '상가') & (test['임대보증금'].isnull())]
# Out:
#      단지코드  총세대수 임대건물구분     지역  공급유형   전용면적  전용면적별세대수   공가수 자격유형 임대보증금  ...  \
# 76  C1006  1505    아파트  대전광역시  영구임대  26.37        10  27.0    D   NaN  ...
# 77  C1006  1505    아파트  대전광역시  영구임대  26.37        10  27.0    D   NaN  ...
# 79  C1006  1505    아파트  대전광역시  영구임대  52.74         6  27.0    D   NaN  ...
#
#    10분내지하철수  10분내버스정류장수  단지내주차면수  단지코드_Type  임대건물구분_lbl  지역_lbl  공급유형_lbl  \
# 76      2.0         5.0    428.0        3.0           1       2         3
# 77      2.0         5.0    428.0        3.0           1       2         3
# 79      2.0         5.0    428.0        3.0           1       2         3
#
#     자격유형_lbl  단지코드_lbl  qcut_총세대수
# 76         4         4          4
# 77         4         4          4
# 79         4         4          4
#
# [3 rows x 21 columns]

# %%
train.loc[train['단지코드'] == 'C1004'].head()
# Out:
#       단지코드  총세대수 임대건물구분    지역  공급유형   전용면적  전용면적별세대수  공가수 자격유형    임대보증금  ...  \
# 756  C1004   521    아파트  충청남도  영구임대  39.30       240  3.0    C  4682000  ...
# 757  C1004   521    아파트  충청남도  영구임대  39.69       264  3.0    C  4728000  ...
# 758  C1004   521     상가  충청남도  임대상가  19.00         1  3.0    D      NaN  ...
# 759  C1004   521     상가  충청남도  임대상가  14.10         1  3.0    D      NaN  ...
# 760  C1004   521     상가  충청남도  임대상가  19.31         1  3.0    D      NaN  ...
#
#     단지내주차면수  단지코드_Type  임대건물구분_lbl  지역_lbl  공급유형_lbl  자격유형_lbl  단지코드_lbl  \
# 756   153.0        3.0           1       7         3         3         2
# 757   153.0        3.0           1       7         3         3         2
# 758   153.0        3.0           2       7         4         4         2
# 759   153.0        3.0           2       7         4         4         2
# 760   153.0        3.0           2       7         4         4         2
#
#      qcut_총세대수  등록차량수  log_등록차량수
# 756          1   93.0   4.543295
# 757          1   93.0   4.543295
# 758          1   93.0   4.543295
# 759          1   93.0   4.543295
# 760          1   93.0   4.543295
#
# [5 rows x 23 columns]

# %%
len(train.loc[train['임대건물구분'] == '상가'])
# Out:
# 562

# %%
all_df.loc[all_df['임대보증금'].isna(), '임대보증금'] = 0
all_df.loc[all_df['임대보증금'] == '-', '임대보증금'] = 0
all_df['임대보증금'] = all_df['임대보증금'].astype(float)


all_df.loc[all_df['임대료'].isna(), '임대료'] = 0
all_df.loc[all_df['임대료'] == '-', '임대료'] = 0
all_df['임대료'] = all_df['임대료'].astype(float)

# %%
list =[('아파트', '충청남도', '국민임대'),('아파트', '충청남도', '영구임대'), ('아파트', '대전광역시', '국민임대'),
       ('아파트', '대전광역시', '영구임대'),('아파트', '대전광역시','공공임대(10년)'),
    ('아파트', '대전광역시', '공공임대(분납)'),('상가', '대전광역시', '임대상가'),('아파트', '경상남도', '공공임대(10년)')]
for i in list:
    grouped = all_df.groupby([ '임대건물구분', '지역','공급유형'])
    group1 = grouped.get_group(i)
    group1['10분내지하철수'].mean()
    group1['10분내지하철수'].fillna(round(group1['10분내지하철수'].mean()), inplace=True)
    all_df.loc[group1.index, '10분내지하철수'] = group1['10분내지하철수']
# Out:
# /opt/anaconda3/envs/dev/lib/python3.7/site-packages/pandas/core/series.py:4469: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %%
grouped = all_df.groupby([ '임대건물구분', '지역','공급유형'])
grouped1 = all_df.groupby([ '임대건물구분', '지역'])
grouped2 = all_df.groupby([ '지역'])
group1 = grouped1.get_group(('아파트', '충청남도'))
group2 = grouped1.get_group(('아파트', '대전광역시'))
group3 = grouped.get_group( ('아파트', '충청남도', '공공임대(50년)')  )
group4 = grouped.get_group( ('아파트', '대전광역시', '공공임대(50년)')  )
group5 = grouped.get_group( ('아파트', '대전광역시', '공공분양')  )
group6 = grouped2.get_group(('충청남도' ))
group7 = grouped.get_group( ('상가', '충청남도', '임대상가')  )
group3['10분내지하철수'].fillna(round(group1['10분내지하철수'].mean()), inplace=True)
all_df.loc[group3.index, '10분내지하철수'] = group3['10분내지하철수']
group4['10분내지하철수'].fillna(round(group2['10분내지하철수'].mean()), inplace=True)
all_df.loc[group4.index, '10분내지하철수'] = group4['10분내지하철수']
group5['10분내지하철수'].fillna(round(group2['10분내지하철수'].mean()), inplace=True)
all_df.loc[group5.index, '10분내지하철수'] = group5['10분내지하철수']
group7['10분내지하철수'].fillna(round(group6['10분내지하철수'].mean()), inplace=True)
all_df.loc[group7.index, '10분내지하철수'] = group7['10분내지하철수']

# %%
all_df.isnull().sum()
# Out:
# 단지코드          0
# 총세대수          0
# 임대건물구분        0
# 지역            0
# 공급유형          0
# 전용면적          0
# 전용면적별세대수      0
# 공가수           0
# 자격유형          0
# 임대보증금         0
# 임대료           0
# 10분내지하철수      0
# 10분내버스정류장수    0
# 단지내주차면수       0
# 단지코드_Type     0
# 임대건물구분_lbl    0
# 지역_lbl        0
# 공급유형_lbl      0
# 자격유형_lbl      0
# 단지코드_lbl      0
# qcut_총세대수     0
# dtype: int64

# %%
train_df = all_df.iloc[0:2896,:]
test_df = all_df.iloc[2896:,:]
train_df.shape, test_df.shape
# Out:
# ((2896, 21), (1008, 21))

# %%
train_df = pd.concat([train_df, train[['등록차량수', 'log_등록차량수']]], axis=1)

# %%
train_df.columns
# Out:
# Index(['단지코드', '총세대수', '임대건물구분', '지역', '공급유형', '전용면적', '전용면적별세대수', '공가수',
#        '자격유형', '임대보증금', '임대료', '10분내지하철수', '10분내버스정류장수', '단지내주차면수',
#        '단지코드_Type', '임대건물구분_lbl', '지역_lbl', '공급유형_lbl', '자격유형_lbl', '단지코드_lbl',
#        'qcut_총세대수', '등록차량수', 'log_등록차량수'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
sel = ['총세대수', '전용면적', '전용면적별세대수', '공가수', '임대보증금', '임대료', '10분내지하철수', '10분내버스정류장수', '단지내주차면수',
       '단지코드_Type', '임대건물구분_lbl', '지역_lbl', '공급유형_lbl', '자격유형_lbl', '단지코드_lbl',
       'qcut_총세대수']

X = train_df[sel]
y = train_df['log_등록차량수']
test_X = test_df[sel]

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
X_train.shape, y_train.shape
# Out:
# ((2172, 16), (2172,))

# %%
from catboost import CatBoostRegressor

model = CatBoostRegressor( 
         loss_function='MAE',
         n_estimators=500, 
         learning_rate=0.05, 
         random_state=42)

model.fit(X, y)
pred = model.predict(test_X)
# Out:
# 0:	learn: 0.6868854	total: 4.81ms	remaining: 2.4s
# 1:	learn: 0.6576599	total: 7.83ms	remaining: 1.95s
# 2:	learn: 0.6328942	total: 12.4ms	remaining: 2.06s
# 3:	learn: 0.6092573	total: 18ms	remaining: 2.23s
# 4:	learn: 0.5851517	total: 22.6ms	remaining: 2.24s
# 5:	learn: 0.5635206	total: 25.8ms	remaining: 2.12s
# 6:	learn: 0.5439246	total: 30.1ms	remaining: 2.12s
# 7:	learn: 0.5250733	total: 33.8ms	remaining: 2.08s
# 8:	learn: 0.5068336	total: 37ms	remaining: 2.02s
# 9:	learn: 0.4912621	total: 41ms	remaining: 2.01s
# 10:	learn: 0.4754124	total: 44.6ms	remaining: 1.98s
# 11:	learn: 0.4608147	total: 48.8ms	remaining: 1.99s
# 12:	learn: 0.4469047	total: 53.6ms	remaining: 2.01s
# 13:	learn: 0.4354648	total: 56.7ms	remaining: 1.97s
# 14:	learn: 0.4225372	total: 60.3ms	remaining: 1.95s
# 15:	learn: 0.4096259	total: 64.2ms	remaining: 1.94s
# 16:	learn: 0.3969363	total: 70.7ms	remaining: 2.01s
# 17:	learn: 0.3865185	total: 74.5ms	remaining: 2s
# 18:	learn: 0.3758599	total: 78.8ms	remaining: 1.99s
# 19:	learn: 0.3648437	total: 83ms	remaining: 1.99s
# 20:	learn: 0.3560744	total: 86.3ms	remaining: 1.97s
# 21:	learn: 0.3474636	total: 89.4ms	remaining: 1.94s
# 22:	learn: 0.3395886	total: 92.8ms	remaining: 1.93s
# 23:	learn: 0.3321639	total: 97ms	remaining: 1.92s
# 24:	learn: 0.3241557	total: 100ms	remaining: 1.91s
# 25:	learn: 0.3172444	total: 107ms	remaining: 1.94s
# 26:	learn: 0.3113130	total: 109ms	remaining: 1.92s
# 27:	learn: 0.3056835	total: 112ms	remaining: 1.9s
# 28:	learn: 0.2995973	total: 116ms	remaining: 1.88s
# 29:	learn: 0.2937132	total: 118ms	remaining: 1.85s
# 30:	learn: 0.2879067	total: 122ms	remaining: 1.84s
# 31:	learn: 0.2815168	total: 125ms	remaining: 1.83s
# 32:	learn: 0.2766918	total: 130ms	remaining: 1.84s
# 33:	learn: 0.2709477	total: 134ms	remaining: 1.83s
# 457:	learn: 0.0796122	total: 1.9s	remaining: 174ms
# 458:	learn: 0.0795590	total: 1.9s	remaining: 170ms
# 459:	learn: 0.0795260	total: 1.91s	remaining: 166ms
# 460:	learn: 0.0794810	total: 1.91s	remaining: 162ms
# 461:	learn: 0.0794501	total: 1.92s	remaining: 158ms
# 462:	learn: 0.0792346	total: 1.92s	remaining: 153ms
# 463:	learn: 0.0791830	total: 1.92s	remaining: 149ms
# 464:	learn: 0.0791544	total: 1.93s	remaining: 145ms
# 465:	learn: 0.0790888	total: 1.93s	remaining: 141ms
# 466:	learn: 0.0790564	total: 1.94s	remaining: 137ms
# 467:	learn: 0.0789711	total: 1.94s	remaining: 133ms
# 468:	learn: 0.0789174	total: 1.95s	remaining: 129ms
# 469:	learn: 0.0788022	total: 1.95s	remaining: 124ms
# 470:	learn: 0.0786599	total: 1.95s	remaining: 120ms
# 471:	learn: 0.0784795	total: 1.95s	remaining: 116ms
# 472:	learn: 0.0783927	total: 1.96s	remaining: 112ms
# 473:	learn: 0.0783654	total: 1.96s	remaining: 108ms
# 474:	learn: 0.0782506	total: 1.97s	remaining: 104ms
# 475:	learn: 0.0782417	total: 1.97s	remaining: 99.4ms
# 476:	learn: 0.0781805	total: 1.97s	remaining: 95.2ms
# 477:	learn: 0.0781271	total: 1.98s	remaining: 91ms
# 478:	learn: 0.0780840	total: 1.98s	remaining: 86.8ms
# 479:	learn: 0.0778386	total: 1.98s	remaining: 82.6ms
# 480:	learn: 0.0777053	total: 1.99s	remaining: 78.5ms
# 481:	learn: 0.0775495	total: 1.99s	remaining: 74.4ms
# 482:	learn: 0.0775324	total: 2s	remaining: 70.2ms
# 483:	learn: 0.0773640	total: 2s	remaining: 66ms
# 484:	learn: 0.0773118	total: 2s	remaining: 61.9ms
# 485:	learn: 0.0772660	total: 2s	remaining: 57.7ms
# 486:	learn: 0.0772265	total: 2.01s	remaining: 53.6ms
# 487:	learn: 0.0771957	total: 2.01s	remaining: 49.5ms
# 488:	learn: 0.0771559	total: 2.02s	remaining: 45.3ms
# 489:	learn: 0.0770727	total: 2.02s	remaining: 41.2ms
# 490:	learn: 0.0770466	total: 2.02s	remaining: 37.1ms
# 491:	learn: 0.0770155	total: 2.03s	remaining: 33ms
# 492:	learn: 0.0769457	total: 2.03s	remaining: 28.9ms
# 493:	learn: 0.0768832	total: 2.04s	remaining: 24.7ms
# 494:	learn: 0.0768195	total: 2.04s	remaining: 20.6ms
# 495:	learn: 0.0767479	total: 2.04s	remaining: 16.5ms
# 496:	learn: 0.0767175	total: 2.04s	remaining: 12.3ms
# 497:	learn: 0.0766073	total: 2.05s	remaining: 8.23ms
# 498:	learn: 0.0765758	total: 2.05s	remaining: 4.12ms
# 499:	learn: 0.0765381	total: 2.06s	remaining: 0us

# %%
test_df['등록차량수'] = np.expm1(pred)   # np.log1 복구
test_df['단지별차량수평균'] = test_df.groupby("단지코드")['등록차량수'].transform(np.mean)
test_new = test_df.drop_duplicates(['단지코드'], keep='first').reset_index() # 중복 제거
test_new
# Out:
# /opt/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      index   단지코드  총세대수 임대건물구분       지역  공급유형   전용면적  전용면적별세대수   공가수 자격유형  \
# 0     2896  C1072   754    아파트      경기도  국민임대  39.79       116  14.0    H
# 1     2904  C1128  1354    아파트      경기도  국민임대  39.79       368   9.0    H
# 2     2913  C1456   619    아파트    부산광역시  국민임대  33.40        82  18.0    A
# 3     2922  C1840   593    아파트     전라북도  국민임대  39.57       253   7.0    A
# 4     2926  C1332  1297    아파트      경기도  국민임대  39.99       282  11.0    H
# ..     ...    ...   ...    ...      ...   ...    ...       ...   ...  ...
# 142   3878  C2456   349    아파트  제주특별자치도  국민임대  26.44        24  17.0    H
# 143   3882  C1266   596    아파트     충청북도  국민임대  26.94       164  35.0    H
# 144   3887  C2152   120    아파트      강원도  영구임대  24.83        66   9.0    C
# 145   3889  C1267   675    아파트     경상남도  국민임대  24.87        28  38.0    H
# 146   3900  C2189   382    아파트     전라북도  국민임대  29.19        96  45.0    H
#
#      ...  단지내주차면수  단지코드_Type  임대건물구분_lbl  지역_lbl  공급유형_lbl  자격유형_lbl  \
# 0    ...    683.0        3.0           1       3         1         8
# 1    ...   1216.0        3.0           1       3         1         8
# 2    ...    547.0        3.0           1       8         1         1
# 3    ...    543.0        3.0           1       4         1         1
# 4    ...   1112.0        3.0           1       3         1         8
# ..   ...      ...        ...         ...     ...       ...       ...
# 142  ...    270.0        1.0           1       9         1         8
# 143  ...    593.0        1.0           1      11         1         8
# 144  ...     40.0        3.0           1       5         3         3
# 145  ...    467.0        1.0           1       1         1         8
# 146  ...    300.0        1.0           1       4         1         8
#
#      단지코드_lbl  qcut_총세대수        등록차량수     단지별차량수평균
# 0          32          2   683.662377   696.218621
# 1          43          4  1134.398677  1178.098397
# 2         143          1   551.886319   587.834521
# 3         263          1   593.997414   614.232560
# 4         110          4  1148.340507  1163.841553
# ..        ...        ...          ...          ...
# 142       471          0   173.371017   194.216645
# 143        85          1   419.204597   415.477497
# 144       369          0    42.256581    43.679576
# 145        86          2   394.079182   368.160155
# 146       381          0   176.446461   187.959236
#
# [147 rows x 24 columns]

# %%
# 제출용 데이터 셋 처리 완료
add_dat = {'code':['C2675', 'C2335', 'C1327'],
           'num':['0', '0', '0']}
add_df = pd.DataFrame(add_dat)

# %%
sub_df = test_new[ ['단지코드', '단지별차량수평균']]
sub_df.columns = ['code', 'num']
sub_df = pd.concat([sub_df, add_df]).reset_index()
sub_df = sub_df.drop(['index'], axis=1)
sub_df
# Out:
#       code          num
# 0    C1072   696.218621
# 1    C1128  1178.098397
# 2    C1456   587.834521
# 3    C1840    614.23256
# 4    C1332  1163.841553
# ..     ...          ...
# 145  C1267   368.160155
# 146  C2189   187.959236
# 147  C2675            0
# 148  C2335            0
# 149  C1327            0
#
# [150 rows x 2 columns]

# %%
sub_df.to_csv('./baseline_0726.csv', index=False)
sub_df.head()
# Out:
#     code          num
# 0  C1072   696.218621
# 1  C1128  1178.098397
# 2  C1456   587.834521
# 3  C1840    614.23256
# 4  C1332  1163.841553
